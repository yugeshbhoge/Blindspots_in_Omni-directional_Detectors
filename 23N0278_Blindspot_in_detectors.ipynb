# %% [markdown]
# ### Getting GPS and UTC time

# %%
from datetime import datetime, timedelta
import time

def gps():
    ep = datetime(1980, 1, 6, 0, 0, 0)
    now = datetime.utcnow()
    diff = now - ep
    sec = int(diff.total_seconds())
    ls = 18
    sec += ls
    return sec

g_time = gps()
print("Current GPS time in seconds:", g_time)
g_time

# %%
utc = datetime.utcnow()
sec = time.mktime(utc.timetuple()) + utc.microsecond / 1e6
print("Current UTC time in seconds:", int(sec))

# %% [markdown]
# # Computing and Plotting Sensitivity pattern for detectors

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import time
import lal
from pycbc.detector import Detector
from joblib import Parallel, delayed

ra = np.linspace(0, 2 * np.pi, 360)
dec = np.linspace(-np.pi/2, np.pi/2, 180)
# t = lal.LIGOTimeGPS(time.time())

t=1e10 + 8000 #A time when ra ~ lines up with lats/longs coordinates 

#Function to calculate the sensitivity of the detectors over ra and dec
def calc_sens(det_name, ra, dec, t):
    det = Detector(det_name)
    sens = np.zeros((len(dec), len(ra)))
    for i, r in enumerate(ra):
        for j, d in enumerate(dec):
            Fp, Fc = det.antenna_pattern(r, d, 0, t)
            sens[j, i] = np.sqrt(Fp**2 + Fc**2)
    return sens

#Calculating the sensitivity of the detectors using above function
det_names =  ['H1','L1', 'V1'] #['H1','L1','K1','I1','V1']
res = Parallel(n_jobs=-1)(delayed(calc_sens)(name, ra, dec, t) for name in det_names)
sens_map = np.sum(res, axis=0)
lats = np.degrees(dec)
longs = np.degrees(ra)

fig = plt.figure(figsize=(12, 6), facecolor="#111827")

#Transforming into Mollweide projection
ax = plt.axes(projection=ccrs.Mollweide())
lg, lt = np.meshgrid(longs, lats)

#Plottting sensitivity pattern in PlateCarree (Rectangular) projection
ctr = ax.contourf(lg, lt, sens_map, levels=50, cmap='viridis', transform=ccrs.PlateCarree(), extend='both')
# ax.coastlines()
gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='white', alpha=0.7, linestyle='--')
gl.top_labels = False
gl.right_labels = False
cbar = plt.colorbar(ctr, orientation='horizontal', pad=0.07, aspect=40)
cbar.set_label('Network Sensitivity', color='white')
cbar.ax.tick_params(colors='white')
cbar.outline.set_edgecolor('white')
# plt.title("LIGO Hanford, Livingstone, India and Virgo and KAGRA  GW signal Sensitivity (Mollweide)", fontsize=14)
plt.title("LIGO Hanford, Livingston and VIRGO GW signal Sensitivity (Mollweide)", fontsize=14, color='white')
# plt.savefig('H1_L1_I1_V1_K1.pdf', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import lal
from pycbc.detector import Detector
from joblib import Parallel, delayed
from itertools import combinations

ra  = np.linspace(0, 2 * np.pi, 360)
dec = np.linspace(-np.pi / 2, np.pi / 2, 180)
t   = 1e10 + 8000

def calc_sens(det_name, ra, dec, t):
    det  = Detector(det_name)
    sens = np.zeros((len(dec), len(ra)))
    for i, r in enumerate(ra):
        for j, d in enumerate(dec):
            Fp, Fc = det.antenna_pattern(r, d, 0, t)
            sens[j, i] = np.sqrt(Fp**2 + Fc**2)
    return sens

ALL_DETS = ['H1', 'L1', 'V1', 'K1', 'I1']

# ── per-detector maps once ───────────────────────────────────
print("Computing individual detector maps …")
per_det = {
    name: calc_sens(name, ra, dec, t)
    for name in ALL_DETS
}

# ── every combination and global min / max ─────────────
combos = []
for r in range(1, len(ALL_DETS) + 1):
    for combo in combinations(ALL_DETS, r):
        sens_map = np.sum([per_det[d] for d in combo], axis=0)
        combos.append((combo, sens_map))

all_values = np.concatenate([m.ravel() for _, m in combos])
VMIN, VMAX = all_values.min(), all_values.max()
LEVELS     = np.linspace(VMIN, VMAX, 51)

print(f"Global sensitivity range: [{VMIN:.3f}, {VMAX:.3f}]")

# ── plot with shared scale ──────────────────────────────────────
lats  = np.degrees(dec)
longs = np.degrees(ra)
lg, lt = np.meshgrid(longs, lats)

for combo, sens_map in combos:
    title = " + ".join(combo) + " GW Signal Sensitivity (Mollweide)"

    fig = plt.figure(figsize=(12, 6), facecolor="#111827")
    ax  = plt.axes(projection=ccrs.Mollweide())
    ax.set_facecolor("#111827")

    ctr = ax.contourf(
        lg, lt, sens_map,
        levels    = LEVELS,
        cmap      = 'viridis',
        transform = ccrs.PlateCarree(),
        extend    = 'both',
        vmin      = VMIN,
        vmax      = VMAX,
    )

    # ── min / max location ──────────────────────────────────────────────────
    min_idx = np.unravel_index(np.argmin(sens_map), sens_map.shape)
    max_idx = np.unravel_index(np.argmax(sens_map), sens_map.shape)

    min_val = sens_map[min_idx]
    max_val = sens_map[max_idx]
    min_ra  = longs[min_idx[1]]   # column → RA (degrees)
    min_dec = lats[min_idx[0]]    # row    → Dec (degrees)
    max_ra  = longs[max_idx[1]]
    max_dec = lats[max_idx[0]]

    # ── markers ──────────────────────────────────────────────────────────────
    common_kw = dict(transform=ccrs.PlateCarree(), zorder=5)
    ax.plot(min_ra, min_dec, 'v', color='cyan',   ms=8,  **common_kw)
    ax.plot(max_ra, max_dec, '*', color='yellow',  ms=12, **common_kw)

    # ── annotations ────────────────────────────────────────────────────
    text_kw = dict(
        transform = ccrs.PlateCarree(),
        fontsize  = 8,
        zorder    = 6,
        ha        = 'left',
        bbox      = dict(boxstyle='round,pad=0.3', fc='#111827', alpha=0.7, ec='none'),
    )

    ax.text(min_ra + 3, min_dec + 3,
            f"Min: {min_val:.2f}\n(RA {min_ra:.1f}°, Dec {min_dec:.1f}°)",
            color='cyan', **text_kw)

    ax.text(max_ra + 3, max_dec + 3,
            f"Max: {max_val:.2f}\n(RA {max_ra:.1f}°, Dec {max_dec:.1f}°)",
            color='yellow', **text_kw)

    # ── cbar ─────────────────────────────────────────────────────────────
    cbar = plt.colorbar(ctr, orientation='horizontal', pad=0.07, aspect=40)
    cbar.set_label('Network Sensitivity', color='white')
    cbar.ax.tick_params(colors='white')
    cbar.outline.set_edgecolor('white')

    plt.title(title, fontsize=13, color='white')
    plt.tight_layout()

    fname = "_".join(combo) + ".pdf"
    plt.savefig(fname, dpi=150, facecolor=fig.get_facecolor())
    plt.show()
    print(f"Saved {fname}  |  Min: {min_val:.2f} @ RA {min_ra:.1f}° Dec {min_dec:.1f}°  |  Max: {max_val:.2f} @ RA {max_ra:.1f}° Dec {max_dec:.1f}°")

# %%
#Plot of subplots
plot_items = [
    ("H1", per_det["H1"]),
    ("H1 + L1 + V1", per_det["H1"] + per_det["L1"] + per_det["V1"]),
    ("H1 + L1 + V1 + K1", per_det["H1"] + per_det["L1"] + per_det["V1"] + per_det["K1"]),
    ("H1 + L1 + V1 + K1 + I1", sum(per_det[d] for d in ALL_DETS)),
]

fig, axes = plt.subplots(
    2, 2,
    figsize=(16, 9),
    subplot_kw={"projection": ccrs.Mollweide()},
    facecolor="#111827"
)
axes = axes.ravel()

mappable = None

for ax_i, (label, s_map_i) in zip(axes, plot_items):
    ax_i.set_facecolor("#111827")

    mappable = ax_i.contourf(
        lg, lt, s_map_i,
        levels=LEVELS,
        cmap="viridis",
        transform=ccrs.PlateCarree(),
        extend="both",
        vmin=VMIN,
        vmax=VMAX
    )

    # min / max points
    min_idx_i = np.unravel_index(np.argmin(s_map_i), s_map_i.shape)
    max_idx_i = np.unravel_index(np.argmax(s_map_i), s_map_i.shape)

    min_val_i = s_map_i[min_idx_i]
    max_val_i = s_map_i[max_idx_i]
    min_ra_i, min_dec_i = longs[min_idx_i[1]], lats[min_idx_i[0]]
    max_ra_i, max_dec_i = longs[max_idx_i[1]], lats[max_idx_i[0]]

    # markers
    ax_i.plot(min_ra_i, min_dec_i, "v", color="cyan", ms=7, transform=ccrs.PlateCarree(), zorder=5)
    ax_i.plot(max_ra_i, max_dec_i, "*", color="yellow", ms=10, transform=ccrs.PlateCarree(), zorder=5)

    # annotations
    ann_kw = dict(
        transform=ccrs.PlateCarree(),
        fontsize=7,
        zorder=6,
        ha="left",
        bbox=dict(boxstyle="round,pad=0.25", fc="#111827", alpha=0.75, ec="none"),
    )
    ax_i.text(
        min_ra_i + 3, min_dec_i + 3,
        f"Min: {min_val_i:.3f}\n(RA {min_ra_i:.1f}°, Dec {min_dec_i:.1f}°)",
        color="cyan", **ann_kw
    )
    ax_i.text(
        max_ra_i + 3, max_dec_i + 3,
        f"Max: {max_val_i:.3f}\n(RA {max_ra_i:.1f}°, Dec {max_dec_i:.1f}°)",
        color="yellow", **ann_kw
    )

    gl_i = ax_i.gridlines(draw_labels=False, linewidth=0.4, color="white", alpha=0.35, linestyle="--")
    ax_i.set_title(label, color="white", fontsize=11)

# Single colorbar for all subplots
cbar_ax = fig.add_axes([0.15, 0.03, 0.7, 0.02])  
# [left, bottom, width, height] in figure coordinates

cbar = fig.colorbar(mappable, cax=cbar_ax, orientation="horizontal")

cbar.set_label("Network Sensitivity", color="white")
cbar.ax.tick_params(colors="white")
cbar.outline.set_edgecolor("white")

fig.suptitle("Detector Network Sensitivity Comparison (Mollweide)", color="white", fontsize=14, y=0.98)
plt.subplots_adjust(
    left=0.03, right=0.97,
    top=0.93, bottom=0.08,
    wspace=0.04, hspace=0.05
)
plt.savefig("Detector_Network_Sensitivity_Comparison.pdf", dpi=150, facecolor=fig.get_facecolor())
plt.show()
